# %% [markdown]
# # load libraries and data

# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

total_out = Path(os.getcwd()+'/Statin_preprocess.csv')
total_data= pd.read_csv(total_out)

target ='mace'
unused_feat = ['interval_statin']

# mri feature가 시작하는 column의 index 구하기
# np.where의 결과값이 array에 들어가기 때문에 방금 계산해 넣어놓은 [0]번째 값을 가져온다.
start_features_index = np.where(total_data.columns.values == "group_after_detail_1")[0][0]
features = list(total_data.columns[start_features_index:])

print(total_data.shape)
print(features)

Num_feat = 25
# Out:
# (122398, 27)
# ['group_after_detail_1', 'statin_drug', 'AGE', 'SEX', 'HTN', 'ICDHTN', 'trt_ICD_DM', 'DM', 'BMI', 'WAIST', 'BP_HIGH', 'BP_LWST', 'BLDS', 'TOT_CHOLE', 'TRIGLYCERIDE', 'HDL_CHOLE', 'LDL_CHOLE', 'HMG', 'smoking', 'econo', 'drinking', 'HMG.1', 'LDL_CHOLE.1', 'current_ascvd', 'risk']

# %%
def feature(Num_feat, clf, test_data_processed, features):
    importance =clf.feature_importances_
    #plt.plot(importance)
    #plt.show()
    labels_importance=importance.argsort()[::-1]

    importance_sort = np.sort(importance)[::-1]

    feat_name_sort=test_data_processed[features].columns[labels_importance]
    important_features = pd.DataFrame() 
    
    for i in range (Num_feat):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])

    return important_features.reset_index(drop=True)

# %% [markdown]
# # Finding best parameters

# %%
# Augmented
import torch
import itertools
from sklearn.metrics import confusion_matrix
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm


def find_bestpar(train_data, test_data, features):
    
    valid_cut = (int)(len(train_data)*0.8)
    for_Train = train_data[:valid_cut]
    for_Validation = train_data[valid_cut:]
    
    """train data 생성"""
    X_train = for_Train[features].values
    Y_train = for_Train[target].values
    
    """valid data 생성"""
    X_valid = for_Validation[features].values
    Y_valid = for_Validation[target].values
    
    """test data 생성"""
    X_test = test_data[features].values
    Y_test = test_data[target].values
    
    print(len(X_train), len(X_valid), len(X_test))            
    
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    
    """
    # define hyperparameter space : learning rate, 
    n_ = [4,8,16]                              # 
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4] # learning rate
    w_ = [0.01, 0.001, 0.0001]                 # weight decay
    g_ = [0.95, 0.99, 0.9]                     # scheduler params - gamma
    ss_ = [10, 20, 30]                         # scheduler params - step_size
    """
    # Orginal hyperparameter space 
    
    # define hyperparameter space (quick version)
    n_ = [4,16]
    lr_ = [2e-2,1e-3]
    w_ = [0.01,0.001]
    g_ = [0.95,0.99]
    ss_ = [10,30]
    
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    print("start training")
    count=0
    for hy in tqdm(h_space):
        count = count + 1
        clf = TabNetClassifier(n_a = hy[0],
                                n_d = hy[0],
                                optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                                scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                                scheduler_fn=torch.optim.lr_scheduler.StepLR,
                                verbose=0)

        clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
                    eval_name=['train', 'valid'], eval_metric=['auc'],
                    max_epochs=200 , patience=20)
       
        preds_acc = clf.predict(X_test)
        preds_prob = clf.predict_proba(X_test)
        test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
        test_acc = accuracy_score(preds_acc, Y_test)
            
        print('Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f%%'%test_auc, 'Test ACC: %.3f%%'%test_acc)
    
        if np.mean(test_auc)>max_auc:
            print("Find new maximum test AUC!!\n")
            max_hy = hy
            max_valid_score = clf.best_cost
            max_auc = test_auc
            max_acc = test_acc
    
    return clf, max_hy, max_valid_score, max_auc, max_acc

# %%
def preprocessing (total_data):
    total_data_processed= total_data.fillna(0).reset_index(drop=True)
    
    # frac: 전체 row 중 몇 %를 반환할 지 결정 -> frac=1을 설정해서 모든 데이터를 반환
    # random_state: 추후 이것과 동일한 샘플링을 재현하기 위함
    # sample: 데이터에서 임의의 샘플 선정 -> frac=1이면 전체 data의 순서만 임의로 바뀜
    total_data_processed = total_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)
    
    print("done preprocessing")
    return total_data_processed

total_data = preprocessing(total_data)
print(len(total_data))
# Out:
# done preprocessing
# 122398

# %%
train_cut = (int)(len(total_data)*0.8)
#print(train_cut)                 

train_data = total_data[:train_cut] 
test_data = total_data[train_cut:] 
#print(len(train_data), len(test_data))
clf, max_hy, max_valid_score, max_test_auc, max_test_acc = find_bestpar(train_data, test_data, features)
# Out:
# 78334 19584 24480
# start training
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=32.0), HTML(value='')))
# Device used : cuda
#
# Early stopping occured at epoch 23 with best_epoch = 3 and best_valid_auc = 0.72155
# Best weights from best epoch are automatically used!
# Valid score: 0.721545 Test AUC: 0.727% Test ACC: 0.960%
# Find new maximum test AUC!!
#
# Device used : cuda
#
# Early stopping occured at epoch 23 with best_epoch = 3 and best_valid_auc = 0.72155
# Best weights from best epoch are automatically used!
# Valid score: 0.721545 Test AUC: 0.727% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 23 with best_epoch = 3 and best_valid_auc = 0.72155
# Best weights from best epoch are automatically used!
# Valid score: 0.721545 Test AUC: 0.727% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 23 with best_epoch = 3 and best_valid_auc = 0.72155
# Best weights from best epoch are automatically used!
# Valid score: 0.721545 Test AUC: 0.727% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 35 with best_epoch = 15 and best_valid_auc = 0.71958
# Best weights from best epoch are automatically used!
# Valid score: 0.719576 Test AUC: 0.724% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 22 and best_valid_auc = 0.72329
# Best weights from best epoch are automatically used!
# Valid score: 0.723286 Test AUC: 0.725% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 19 and best_valid_auc = 0.72291
# Best weights from best epoch are automatically used!
# Valid score: 0.722911 Test AUC: 0.730% Test ACC: 0.960%
# Find new maximum test AUC!!
#
# Device used : cuda
#
# Early stopping occured at epoch 42 with best_epoch = 22 and best_valid_auc = 0.72329
# Best weights from best epoch are automatically used!
# Valid score: 0.723286 Test AUC: 0.725% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 85 with best_epoch = 65 and best_valid_auc = 0.72646
# Best weights from best epoch are automatically used!
# Valid score: 0.726458 Test AUC: 0.731% Test ACC: 0.960%
# Find new maximum test AUC!!
#
# Device used : cuda
#
# Early stopping occured at epoch 85 with best_epoch = 65 and best_valid_auc = 0.72583
# Best weights from best epoch are automatically used!
# Valid score: 0.725833 Test AUC: 0.731% Test ACC: 0.960%
# Find new maximum test AUC!!
#
# Device used : cuda
#
# Early stopping occured at epoch 64 with best_epoch = 44 and best_valid_auc = 0.7262
# Best weights from best epoch are automatically used!
# Valid score: 0.726198 Test AUC: 0.729% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 91 with best_epoch = 71 and best_valid_auc = 0.72531
# Best weights from best epoch are automatically used!
# Valid score: 0.725307 Test AUC: 0.729% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 125 with best_epoch = 105 and best_valid_auc = 0.72161
# Best weights from best epoch are automatically used!
# Valid score: 0.721614 Test AUC: 0.719% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 70 with best_epoch = 50 and best_valid_auc = 0.7141
# Best weights from best epoch are automatically used!
# Valid score: 0.714101 Test AUC: 0.706% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 112 with best_epoch = 92 and best_valid_auc = 0.71896
# Best weights from best epoch are automatically used!
# Valid score: 0.718963 Test AUC: 0.723% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 108 with best_epoch = 88 and best_valid_auc = 0.72088
# Best weights from best epoch are automatically used!
# Valid score: 0.720882 Test AUC: 0.719% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 10 and best_valid_auc = 0.71889
# Best weights from best epoch are automatically used!
# Valid score: 0.718892 Test AUC: 0.726% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.72039
# Best weights from best epoch are automatically used!
# Valid score: 0.720391 Test AUC: 0.727% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 30 with best_epoch = 10 and best_valid_auc = 0.71906
# Best weights from best epoch are automatically used!
# Valid score: 0.719059 Test AUC: 0.727% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.72039
# Best weights from best epoch are automatically used!
# Valid score: 0.720391 Test AUC: 0.727% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 33 with best_epoch = 13 and best_valid_auc = 0.72129
# Best weights from best epoch are automatically used!
# Valid score: 0.721292 Test AUC: 0.729% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 43 with best_epoch = 23 and best_valid_auc = 0.72074
# Best weights from best epoch are automatically used!
# Valid score: 0.720744 Test AUC: 0.728% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 31 with best_epoch = 11 and best_valid_auc = 0.72118
# Best weights from best epoch are automatically used!
# Valid score: 0.721184 Test AUC: 0.728% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 43 with best_epoch = 23 and best_valid_auc = 0.72074
# Best weights from best epoch are automatically used!
# Valid score: 0.720744 Test AUC: 0.728% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 82 with best_epoch = 62 and best_valid_auc = 0.72745
# Best weights from best epoch are automatically used!
# Valid score: 0.727445 Test AUC: 0.730% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.72767
# Best weights from best epoch are automatically used!
# Valid score: 0.727670 Test AUC: 0.730% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 63 with best_epoch = 43 and best_valid_auc = 0.72545
# Best weights from best epoch are automatically used!
# Valid score: 0.725451 Test AUC: 0.728% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 61 with best_epoch = 41 and best_valid_auc = 0.72587
# Best weights from best epoch are automatically used!
# Valid score: 0.725871 Test AUC: 0.728% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 78 with best_epoch = 58 and best_valid_auc = 0.71479
# Best weights from best epoch are automatically used!
# Valid score: 0.714795 Test AUC: 0.721% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 81 with best_epoch = 61 and best_valid_auc = 0.71655
# Best weights from best epoch are automatically used!
# Valid score: 0.716546 Test AUC: 0.712% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 84 with best_epoch = 64 and best_valid_auc = 0.71604
# Best weights from best epoch are automatically used!
# Valid score: 0.716045 Test AUC: 0.714% Test ACC: 0.960%
# Device used : cuda
#
# Early stopping occured at epoch 95 with best_epoch = 75 and best_valid_auc = 0.71911
# Best weights from best epoch are automatically used!
# Valid score: 0.719114 Test AUC: 0.717% Test ACC: 0.960%

# %%
print("<<Important Feature>>")
import_feat=feature(Num_feat, clf, test_data, features)
import_feat.to_csv(f"MACE_features.csv")
import_feat
# Out:
# <<Important Feature>>
#             feature name     ratio
# 0                   risk  0.204921
# 1          current_ascvd  0.106469
# 2                 ICDHTN  0.078631
# 3                    AGE  0.076417
# 4                    HTN  0.060829
# 5                    SEX  0.054555
# 6                  econo  0.043057
# 7                     DM  0.034735
# 8                    HMG  0.031601
# 9                smoking  0.028486
# 10           statin_drug  0.026990
# 11                   BMI  0.026875
# 12          TRIGLYCERIDE  0.026490
# 13               BP_LWST  0.025853
# 14  group_after_detail_1  0.022889
# 15               BP_HIGH  0.020473
# 16                 WAIST  0.019227
# 17            trt_ICD_DM  0.018583
# 18                 HMG.1  0.017894
# 19             HDL_CHOLE  0.016847
# 20              drinking  0.014295
# 21           LDL_CHOLE.1  0.012269
# 22             TOT_CHOLE  0.011855
# 23             LDL_CHOLE  0.011162
# 24                  BLDS  0.008597

# %%
import xgboost as xgb

"""
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }
"""

train_cut = (int)(len(total_data)*0.8)
#print(train_cut)         

train_data = total_data[:train_cut] 
test_data = total_data[train_cut:] 

X_train = train_data[features].values
y_train = train_data[target].values

X_test = test_data[features].values
y_test = test_data[target].values

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42, eval_metric="auc")
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

print(accuracy_score(y_test, y_pred))
#print(xgb_model.best_params_)
# Out:
# 0.9595179738562092
